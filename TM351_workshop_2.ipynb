# %% [markdown]
# # **Pandas methods and properties**

# %% [markdown]
# **Importing dataset**

# %% [markdown]
# The dataset used in this example here
# https://www.kaggle.com/datasets/gregorut/videogamesales

# %% [markdown]
# 1- A useful Pandas method is the .read_csv() method. It allows us to read a csv into a dataframe as follows:

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\salem\Downloads\Compressed\archive\vgsales.csv",index_col=0)#index_col =0 means I want the first col, Rank, to be my index
df
# Out:
#                                                    Name Platform    Year  \
# Rank
# 1                                            Wii Sports      Wii  2006.0
# 2                                     Super Mario Bros.      NES  1985.0
# 3                                        Mario Kart Wii      Wii  2008.0
# 4                                     Wii Sports Resort      Wii  2009.0
# 5                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16596                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16597                     Men in Black II: Alien Escape       GC  2003.0
# 16598  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16599                                        Know How 2       DS  2010.0
# 16600                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# ...

# %%
df.head(10)# means that I want to print the first 10 rows only
# Out:
#                            Name Platform    Year         Genre Publisher  \
# Rank
# 1                    Wii Sports      Wii  2006.0        Sports  Nintendo
# 2             Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 3                Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 4             Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 5      Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 6                        Tetris       GB  1989.0        Puzzle  Nintendo
# 7         New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 8                      Wii Play      Wii  2006.0          Misc  Nintendo
# 9     New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 10                    Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Rank
# 1        41.49     29.02      3.77         8.46         82.74
# ...

# %%
df.tail(5) #means that I want to print the last 5 rows only
# Out:
#                                                    Name Platform    Year  \
# Rank
# 16596                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16597                     Men in Black II: Alien Escape       GC  2003.0
# 16598  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16599                                        Know How 2       DS  2010.0
# 16600                                  Spirits & Spells      GBA  2003.0
#
#           Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# 16596  Platform       Kemco      0.01      0.00       0.0          0.0
# 16597   Shooter  Infogrames      0.01      0.00       0.0          0.0
# 16598    Racing  Activision      0.00      0.00       0.0          0.0
# 16599    Puzzle    7G//AMES      0.00      0.01       0.0          0.0
# 16600  Platform     Wanadoo      0.01      0.00       0.0          0.0
#
#        Global_Sales
# Rank
# 16596          0.01
# 16597          0.01
# ...

# %%
df.dtypes   #This will give us an overview of what type of data is inside each column.
# Out:
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %% [markdown]
# 2- shape method for number of rows and columns of the dataset

# %%
df.shape
# Out:
# (16598, 10)

# %%
df.info()#To get an overall summary of your data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16598 entries, 1 to 16600
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          16598 non-null  object
#  1   Platform      16598 non-null  object
#  2   Year          16327 non-null  float64
#  3   Genre         16598 non-null  object
#  4   Publisher     16540 non-null  object
#  5   NA_Sales      16598 non-null  float64
#  6   EU_Sales      16598 non-null  float64
#  7   JP_Sales      16598 non-null  float64
#  8   Other_Sales   16598 non-null  float64
#  9   Global_Sales  16598 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# 3- describe method for statistical data about dataset

# %%
df.describe()
# Out:
#                Year      NA_Sales      EU_Sales      JP_Sales   Other_Sales  \
# count  16327.000000  16598.000000  16598.000000  16598.000000  16598.000000
# mean    2006.406443      0.264667      0.146652      0.077782      0.048063
# std        5.828981      0.816683      0.505351      0.309291      0.188588
# min     1980.000000      0.000000      0.000000      0.000000      0.000000
# 25%     2003.000000      0.000000      0.000000      0.000000      0.000000
# 50%     2007.000000      0.080000      0.020000      0.000000      0.010000
# 75%     2010.000000      0.240000      0.110000      0.040000      0.040000
# max     2020.000000     41.490000     29.020000     10.220000     10.570000
#
#        Global_Sales
# count  16598.000000
# mean       0.537441
# std        1.555028
# min        0.010000
# 25%        0.060000
# 50%        0.170000
# 75%        0.470000
# max       82.740000

# %%
#adding the values of two columns and save them in new column called total
df["total"] = df["NA_Sales"] + df["EU_Sales"]
df["total"]
# Out:
# Rank
# 1        70.51
# 2        32.66
# 3        28.73
# 4        26.76
# 5        20.16
#          ...
# 16596     0.01
# 16597     0.01
# 16598     0.00
# 16599     0.01
# 16600     0.01
# Name: total, Length: 16598, dtype: float64

# %% [markdown]
# We can easily index specific elements from the DataFrame. For example, if we want to get the Genre and Year cols of the elements with Rank 2 to 5 (remember this is not their positions), we can use the code below:

# %%
df.loc[2:5,["Year","Genre"]]
# Out:
#         Year         Genre
# Rank
# 2     1985.0      Platform
# 3     2008.0        Racing
# 4     2009.0        Sports
# 5     1996.0  Role-Playing

# %%
df.loc[df['Year'] > 1990] #print items with year greater than 1990
# Out:
#                                                    Name Platform    Year  \
# Rank
# 1                                            Wii Sports      Wii  2006.0
# 3                                        Mario Kart Wii      Wii  2008.0
# 4                                     Wii Sports Resort      Wii  2009.0
# 5                              Pokemon Red/Pokemon Blue       GB  1996.0
# 7                                 New Super Mario Bros.       DS  2006.0
# ...                                                 ...      ...     ...
# 16596                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16597                     Men in Black II: Alien Escape       GC  2003.0
# 16598  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16599                                        Know How 2       DS  2010.0
# 16600                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# ...
